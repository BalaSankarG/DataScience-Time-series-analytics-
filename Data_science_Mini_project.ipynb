# %% [markdown]
# <a href="https://colab.research.google.com/github/BalaSankarG/DataScience-Time-series-analytics-/blob/main/Data_science_Mini_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Time series analysis for univariate, bivariate and multi variate variable using python

# %% [markdown]
# Import the libraries to perform the the time series anlaysis.

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# Mount the google drive to access the downloaded dataset

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# To import the dataset

# %%
f = open('//content/drive/MyDrive/train.csv')

# %%
tips = sns.load_dataset('tips')

# %% [markdown]
# To define the given dataset

# %%
tips.head(100)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# ..         ...   ...     ...    ...  ...     ...   ...
# 95       40.17  4.73    Male    Yes  Fri  Dinner     4
# 96       27.28  4.00    Male    Yes  Fri  Dinner     2
# 97       12.03  1.50    Male    Yes  Fri  Dinner     2
# 98       21.01  3.00    Male    Yes  Fri  Dinner     2
# 99       12.46  1.50    Male     No  Fri  Dinner     2
#
# [100 rows x 7 columns]

# %%
Bass = pd.read_csv('/content/drive/MyDrive/train.csv')

# %%
Boss= sns.load_dataset('flights')

# %%
Boss.head(15)
# Out:
#     year month  passengers
# 0   1949   Jan         112
# 1   1949   Feb         118
# 2   1949   Mar         132
# 3   1949   Apr         129
# 4   1949   May         121
# 5   1949   Jun         135
# 6   1949   Jul         148
# 7   1949   Aug         148
# 8   1949   Sep         136
# 9   1949   Oct         119
# 10  1949   Nov         104
# 11  1949   Dec         118
# 12  1950   Jan         115
# 13  1950   Feb         126
# 14  1950   Mar         141

# %%
Boss
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# The below graph shows the Variance between the total bill and the tip based on the sex.
# The graph is form by the library seaborn.
# In the library scatterplot used for time series variate.

# %%
sns.scatterplot(tips['total_bill'],tips['tip'],hue=tips['sex'],size=tips['size'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# The graph is form by the library matplot seaborn. In the library barplotplot used for time series variate.

# %%
sns.barplot(tips['sex'],tips['total_bill'],hue=tips['size'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# The graph is form by the library matplot libray seaborn. In the library boxplot used for time series variate.
# The graph shows the boxplot for the given dataset.

# %%
sns.boxplot(tips['sex'],tips['tip'],hue=tips['size'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# The given graph shows the differnce between the density and age of the given dataset by the library displot.
# Displot is nothing but combination of histogram and line graph
# Here the peak is in at the level of age 20 tto 40 and the density is at the level 0.035.

# %%
sns.distplot(Bass[Bass['Survived']==0]['Age'],hist=True)
sns.distplot(Bass[Bass['Survived']==1]['Age'],hist=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %% [markdown]
# In the below graph the heatmap is used by the library.
# The crosstab is also used here
# Difference between the survived and Pclass is shown by heatmap graph visualization.

# %%
sns.heatmap(pd.crosstab(tips['size'],tips['sex']))

# %%
(tips.groupby('tip').mean()['total_bill']*100)
# Out:
# tip
# 1.00      716.750000
# 1.01     1699.000000
# 1.10     1290.000000
# 1.17     3283.000000
# 1.25      969.666667
#             ...
# 6.70     3430.000000
# 6.73     4827.000000
# 7.58     3942.000000
# 9.00     4833.000000
# 10.00    5081.000000
# Name: total_bill, Length: 123, dtype: float64

# %% [markdown]
# The given below graph shows the cluster map of given dataset of patch and Pclass.
# It is used ti visualize the cluster effect to show the differnce in visualization of bivariate analysis.
# Level are given to this like 0,100,200,300.

# %%
Boss.head(15)
# Out:
#     year month  passengers
# 0   1949   Jan         112
# 1   1949   Feb         118
# 2   1949   Mar         132
# 3   1949   Apr         129
# 4   1949   May         121
# 5   1949   Jun         135
# 6   1949   Jul         148
# 7   1949   Aug         148
# 8   1949   Sep         136
# 9   1949   Oct         119
# 10  1949   Nov         104
# 11  1949   Dec         118
# 12  1950   Jan         115
# 13  1950   Feb         126
# 14  1950   Mar         141

# %%
sns.clustermap(pd.crosstab(Boss['passengers'],Boss['year']))

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# The given below visualization are made by pair plot function.
# It is formed by difference between all the species given in the dataset.
# It has various types visualization is there.
# The sepal length and the sepal width is used here to visualize this library.

# %%
sns.pairplot(tips,hue='sex')

# %%
Boss
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
new = Boss.groupby('year').sum().reset_index()

# %% [markdown]
# The given below visualization is the line plot
# Line plot is the one of the major visualization effect used in data visualization technique.
# Here the line plot is used to differentiate the no of year and the no of passenger are given in the dataset.
# The year is varies from 1950 to 1960
# The passenger is from 20000 to 50000
# The no of passenger are travel min the flight in year is visualize in the below garph .
# In 1960 the no of passenger is more than the other year .

# %%
sns.lineplot(new['year'],new['passengers'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
Boss
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# The another cluster map is shown for no of flights fly by pivot table concept.
# Here there are three concept is placed by the values of passengers,month and year is differentiate in the cluster map.
# There are some levels are there in the map 200,300,400,500,600.

# %%
sns.clustermap(Boss.pivot_table(values='passengers',index='month',columns='year'))

# %%
#Pivot
pivot = Boss.stack()
pivot
# Out:
# 0    year          1949
#      month          Jan
#      passengers     112
# 1    year          1949
#      month          Feb
#                    ...
# 142  month          Nov
#      passengers     390
# 143  year          1960
#      month          Dec
#      passengers     432
# Length: 432, dtype: object

# %%
pivot.unstack()
# Out:
#      year month passengers
# 0    1949   Jan        112
# 1    1949   Feb        118
# 2    1949   Mar        132
# 3    1949   Apr        129
# 4    1949   May        121
# ..    ...   ...        ...
# 139  1960   Aug        606
# 140  1960   Sep        508
# 141  1960   Oct        461
# 142  1960   Nov        390
# 143  1960   Dec        432
#
# [144 rows x 3 columns]

# %%
# a look at the number of records missing in the dataset:
total = tips.isnull().sum().sort_values(ascending=False)
total
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
import os
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# %%
Boss['passengers'].plot(linewidth=0.5)

# %%
Boss.describe().T
# Out:
#             count         mean         std     min      25%     50%      75%  \
# year        144.0  1954.500000    3.464102  1949.0  1951.75  1954.5  1957.25
# passengers  144.0   280.298611  119.966317   104.0   180.00   265.5   360.50
#
#                max
# year        1960.0
# passengers   622.0

# %%
year = Boss['year']
Passengers= Boss['passengers']

fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.barh(year, Passengers)
# Out:
# <BarContainer object of 144 artists>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
ax=sns.countplot(x=tips.day)

plt.show()

# %%
plt.figure(figsize=(5,5))
ax=sns.countplot(y=tips.day)

plt.show()

# %%
# A histogram groups values into ranges (or bins), and the height of a bar shows how many values fall in that range
import seaborn as sns
sns.histplot(x='day', data=tips)

# %%
# kernel density estimate
# The ‘kernel density estimate’ plot creates a smooth version of a histogram by normalizing all points to appear under one curve.

sns.kdeplot(x='tip', data=tips, hue='size')

# %%
sns.violinplot(x=tips["total_bill"])

# %%
sns.stripplot(x=tips["tip"]);

# %%
xlist = np.linspace(-3.0, 3.0, 100)
ylist = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(xlist, ylist)
Z = np.sqrt(X**2 + Y**2)
fig,ax=plt.subplots(1,1)
cp = ax.contourf(X, Y, Z)
fig.colorbar(cp) # Add a colorbar to a plot
ax.set_title('tip')
#ax.set_xlabel('x (cm)')
ax.set_ylabel('y (cm)')
plt.show()

# %%
x =tips.groupby(['total_bill']).sum()
print(x)
# Out:
#               tip  size
# total_bill
# 3.07         1.00     1
# 5.75         1.00     2
# 7.25         6.15     3
# 7.51         2.00     2
# 7.56         1.44     2
# ...           ...   ...
# 45.35        3.50     3
# 48.17        5.00     6
# 48.27        6.73     4
# 48.33        9.00     4
# 50.81       10.00     3
#
# [229 rows x 2 columns]

# %%
Bass
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
double_grouping = Bass.groupby(["Ticket","Fare"])
double_grouping.first()
# Out:
#                     PassengerId  Survived  Pclass  \
# Ticket      Fare
# 110152      86.500          258         1       1
# 110413      79.650          263         0       1
# 110465      52.000          111         0       1
# 110564      26.550          431         1       1
# 110813      75.250          367         1       1
# ...                         ...       ...     ...
# W./C. 6608  34.375           87         0       3
# W./C. 6609  7.550           236         0       3
# W.E.P. 5734 61.175           93         0       1
# W/C 14208   10.500          220         0       2
# WE/P 5735   71.000          541         1       1
#
#                                                                 Name     Sex  \
# Ticket      Fare
# 110152      86.500                              Cherry, Miss. Gladys  female
# 110413      79.650                                 Taussig, Mr. Emil    male
# 110465      52.000                    Porter, Mr. Walter Chamberlain    male
# ...

# %%
Boss
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
Boss['passengers'].max()
# Out:
# 622

# %%
Boss['passengers'].min()
# Out:
# 104

# %%
tips.mean()
# Out:
# <ipython-input-35-f794d13cf0bf>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   tips.mean()
# total_bill    19.785943
# tip            2.998279
# size           2.569672
# dtype: float64

# %%
Bass
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Bass['Survived'].count
Bass['PassengerId'].count
# Out:
# <bound method Series.count of 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64>

# %%
Bass.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import math
import numpy as np
import pandas as pd
from matplotlib import pyplot
from scipy import stats
mu, sigma = 128, 25 # From the above example
highest_Credits = np.random.normal(mu, sigma, 1000) # Random 1000 values

count, bins, _ = pyplot.hist(highest_Credits, 100, color='lightblue') # plot 100 points
pyplot.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
    np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
    linewidth = 2, color = 'r') # Plot the Bass
